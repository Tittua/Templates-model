# %% [markdown]
# <a href="https://colab.research.google.com/github/Tittua/Templates-model/blob/main/Stock_predictions_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline
from datetime import datetime

# %%
# !pip install nsepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nsepy
#   Downloading nsepy-0.8.tar.gz (33 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from nsepy) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from nsepy) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from nsepy) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nsepy) (1.3.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nsepy) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nsepy) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from nsepy) (4.9.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->nsepy) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->nsepy) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->nsepy) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->nsepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->nsepy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->nsepy) (1.24.3)
# Building wheels for collected packages: nsepy
#   Building wheel for nsepy (setup.py) ... done
#   Created wheel for nsepy: filename=nsepy-0.8-py3-none-any.whl size=36084 sha256=b14c9b2a0ac57a617a75ad7780ef966a1b8d0dda4a3dc41fec6b18475e676392
#   Stored in directory: /root/.cache/pip/wheels/32/ab/d9/78ceea14cdf6de83376082b3cb0c2999fd77f823e35c47b9ec
# Successfully built nsepy
# Installing collected packages: nsepy
# Successfully installed nsepy-0.8

# %%
import pandas as pd
import nsepy
import datetime

# %% [markdown]
# **Importing dataset**

# %%
from datetime import date
end_date=datetime.date.today()
def extract(name):
  data=nsepy.get_history(symbol=name,start=date(2005,1,1),end=end_date)
  return data

# %%
df_sbi=extract('SBIN')
df_axis=extract('AXIS BANK LIMITED')
df_maruti=extract('MARUTI SUZUKI INDIA LIMITED')
df_al=extract('ASHOK LEYLAND LIMITED')
# Out:
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com
# WARNING:urllib3.connectionpool:Connection pool is full, discarding connection: www1.nseindia.com

# %% [markdown]
# **Datasets**

# %%
df_maruti.head()
# Out:
#             Symbol Series  Prev Close   Open    High    Low    Last   Close  \
# Date
# 2005-01-03  MARUTI     EQ      461.90  465.0  472.45  463.1  470.50  470.35
# 2005-01-04  MARUTI     EQ      470.35  472.9  474.00  462.0  462.55  463.85
# 2005-01-05  MARUTI     EQ      463.85  465.0  480.00  430.0  445.00  446.65
# 2005-01-06  MARUTI     EQ      446.65  451.0  454.00  432.0  436.15  436.55
# 2005-01-07  MARUTI     EQ      436.55  440.0  443.80  436.0  440.45  440.65
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2005-01-03  469.09  1538102  7.215059e+13     NaN              249782
# 2005-01-04  467.16  2312917  1.080504e+14     NaN             1017902
# 2005-01-05  452.04  2394444  1.082382e+14     NaN              312262
# 2005-01-06  441.37  2399370  1.059004e+14     NaN              339076
# 2005-01-07  440.39  1223939  5.390145e+13     NaN              165078
#
#             %Deliverble
# Date
# 2005-01-03       0.1624
# 2005-01-04       0.4401
# 2005-01-05       0.1304
# 2005-01-06       0.1413
# 2005-01-07       0.1349

# %%
df_al.head()
# Out:
#               Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2005-01-03  ASHOKLEY     EQ       24.65  25.00  25.25  24.50  24.55  24.60
# 2005-01-04  ASHOKLEY     EQ       24.60  24.95  25.00  23.85  24.05  24.15
# 2005-01-05  ASHOKLEY     EQ       24.15  24.25  24.80  22.00  23.00  23.20
# 2005-01-06  ASHOKLEY     EQ       23.20  24.00  24.00  22.10  22.75  22.90
# 2005-01-07  ASHOKLEY     EQ       22.90  23.25  23.80  22.65  23.20  23.20
#
#              VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2005-01-03  24.75  2898371  7.172742e+12     NaN             1669682
# 2005-01-04  24.22  3615627  8.756396e+12     NaN             2418392
# 2005-01-05  23.49  4295982  1.008994e+13     NaN             2685348
# 2005-01-06  22.88  3891579  8.904952e+12     NaN             1987621
# 2005-01-07  23.22  3032179  7.040755e+12     NaN             1450266
#
#             %Deliverble
# Date
# 2005-01-03       0.5761
# 2005-01-04       0.6689
# 2005-01-05       0.6251
# 2005-01-06       0.5107
# 2005-01-07       0.4783

# %%
df_sbi.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low   Last   Close  \
# Date
# 2005-01-03   SBIN     EQ      652.00  654.50  662.90  650.10  657.0  655.75
# 2005-01-04   SBIN     EQ      655.75  658.85  658.90  646.15  651.0  649.90
# 2005-01-05   SBIN     EQ      649.90  649.95  655.80  591.00  615.8  617.45
# 2005-01-06   SBIN     EQ      617.45  615.25  628.90  596.15  604.0  604.30
# 2005-01-07   SBIN     EQ      604.30  609.40  619.95  605.25  615.9  615.65
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2005-01-03  656.76  2131452  1.399851e+14     NaN            399911.0
# 2005-01-04  651.35  2472630  1.610536e+14     NaN            274312.0
# 2005-01-05  625.10  4919738  3.075329e+14     NaN            592714.0
# 2005-01-06  612.49  4502406  2.757690e+14     NaN            293856.0
# 2005-01-07  613.27  2923563  1.792921e+14     NaN            176542.0
#
#             %Deliverble
# Date
# 2005-01-03       0.1876
# 2005-01-04       0.1109
# 2005-01-05       0.1205
# 2005-01-06       0.0653
# 2005-01-07       0.0604

# %%
df_axis.head()
# Out:
#              Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2005-01-03  UTIBANK     EQ      185.20  185.00  191.00  185.00  190.95
# 2005-01-04  UTIBANK     EQ      190.20  191.10  192.00  187.00  191.50
# 2005-01-05  UTIBANK     EQ      189.70  189.95  189.95  177.55  184.90
# 2005-01-06  UTIBANK     EQ      184.25  184.10  190.00  177.00  182.00
# 2005-01-07  UTIBANK     EQ      185.15  180.65  191.90  180.65  190.75
#
#              Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2005-01-03  190.20  188.89  284202  5.368259e+12     NaN              191822
# 2005-01-04  189.70  189.29  223165  4.224233e+12     NaN              147676
# 2005-01-05  184.25  183.78  232617  4.274973e+12     NaN              150070
# 2005-01-06  185.15  182.76  238522  4.359124e+12     NaN              131421
# 2005-01-07  190.10  186.11  306052  5.695810e+12     NaN              235959
#
#             %Deliverble
# Date
# 2005-01-03       0.6749
# 2005-01-04       0.6617
# 2005-01-05       0.6451
# 2005-01-06       0.5510
# 2005-01-07       0.7710

# %% [markdown]
# **PLOTS**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
features = ['Close','Open','High','Low','Prev Close']

# %%
for i in features:
    plt.figure(figsize=(20,8))
    df_sbi[i].plot(label='SBI')
    df_axis[i].plot(label='AXIS')
    df_maruti[i].plot(label='maruti')
    df_al[i].plot(label='Ashok leyland')
    plt.title(i)
    plt.legend()
    plt.show()

# %% [markdown]
# **Extracting data in CSV format**

# %%
df_sbi.to_csv('sbi.csv')
df_maruti.to_csv('Maruti.csv')
df_axis.to_csv('AXIS.csv')
df_al.to_csv('Ashok leyland.csv')

# %% [markdown]
# **EDA**

# %%
datas=[df_sbi,df_maruti,df_axis,df_al]#Data Frames
names=['SBI','Maruti','AXIS','Ashok leyland']

# %%
#Removing all the unnecessary columns
for i in datas:
  i=i.drop(['Series','VWAP','Trades','Deliverable Volume','%Deliverble','Turnover'],axis=1,inplace=True)

# %% [markdown]
# **Describing the data set**

# %%
df_maruti.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4419.000000  4419.000000  4419.000000  4419.000000  4419.000000
# mean   3542.287022  3547.020468  3589.559188  3501.194705  3543.516644
# std    2928.177279  2932.856672  2960.975401  2900.592244  2928.222089
# min     394.750000   396.000000   406.000000   389.150000   393.500000
# 25%    1027.050000  1026.075000  1049.000000  1002.675000  1028.750000
# 50%    1655.950000  1655.000000  1684.100000  1638.850000  1655.500000
# 75%    6718.700000  6729.975000  6810.000000  6650.000000  6726.000000
# max    9832.450000  9966.000000  9996.400000  9725.000000  9846.000000
#
#              Close        Volume
# count  4419.000000  4.419000e+03
# mean   3544.165999  8.149152e+05
# std    2928.830497  6.543139e+05
# min     394.750000  2.279600e+04
# 25%    1027.175000  4.139565e+05
# 50%    1657.850000  6.386080e+05
# 75%    6721.375000  1.000542e+06
# max    9832.450000  1.056777e+07

# %%
df_axis.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4419.000000  4419.000000  4419.000000  4419.000000  4419.000000
# mean    747.546821   748.294229   760.584453   734.966418   747.686965
# std     355.843619   355.642705   360.447952   351.013479   355.728798
# min     175.650000   176.700000   183.200000   170.000000   176.000000
# 25%     491.075000   493.350000   500.100000   483.675000   491.075000
# 50%     663.900000   664.000000   675.250000   652.300000   664.150000
# 75%     999.750000  1000.000000  1019.825000   980.100000   999.000000
# max    2023.350000  2034.400000  2043.050000  2002.600000  2022.550000
#
#              Close        Volume
# count  4419.000000  4.419000e+03
# mean    747.705137  6.190394e+06
# std     355.761222  8.658247e+06
# min     175.650000  2.779900e+04
# 25%     491.250000  1.256564e+06
# 50%     663.900000  3.334177e+06
# 75%     999.750000  7.771347e+06
# max    2023.350000  1.205419e+08

# %%
df_maruti.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4419.000000  4419.000000  4419.000000  4419.000000  4419.000000
# mean   3542.287022  3547.020468  3589.559188  3501.194705  3543.516644
# std    2928.177279  2932.856672  2960.975401  2900.592244  2928.222089
# min     394.750000   396.000000   406.000000   389.150000   393.500000
# 25%    1027.050000  1026.075000  1049.000000  1002.675000  1028.750000
# 50%    1655.950000  1655.000000  1684.100000  1638.850000  1655.500000
# 75%    6718.700000  6729.975000  6810.000000  6650.000000  6726.000000
# max    9832.450000  9966.000000  9996.400000  9725.000000  9846.000000
#
#              Close        Volume
# count  4419.000000  4.419000e+03
# mean   3544.165999  8.149152e+05
# std    2928.830497  6.543139e+05
# min     394.750000  2.279600e+04
# 25%    1027.175000  4.139565e+05
# 50%    1657.850000  6.386080e+05
# 75%    6721.375000  1.000542e+06
# max    9832.450000  1.056777e+07

# %%
df_al.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  4419.000000  4419.000000  4419.000000  4419.000000  4419.000000
# mean     63.862039    64.047567    65.111688    62.749231    63.920978
# std      38.706462    38.801773    39.275667    38.201985    38.728262
# min      11.850000    11.850000    12.250000    11.750000    11.800000
# 25%      30.350000    30.600000    31.250000    29.600000    30.325000
# 50%      51.700000    51.700000    52.750000    50.600000    51.750000
# 75%      90.600000    90.900000    92.050000    89.250000    90.725000
# max     166.550000   166.550000   169.450000   164.900000   166.400000
#
#              Close        Volume
# count  4419.000000  4.419000e+03
# mean     63.889636  1.231887e+07
# std      38.720819  1.425604e+07
# min      11.850000  2.704700e+04
# 25%      30.350000  3.893488e+06
# 50%      51.700000  8.060242e+06
# 75%      90.600000  1.554369e+07
# max     166.550000  2.450100e+08

# %%
df_sbi.index
# Out:
# Index([2005-01-03, 2005-01-04, 2005-01-05, 2005-01-06, 2005-01-07, 2005-01-10,
#        2005-01-11, 2005-01-12, 2005-01-13, 2005-01-14,
#        ...
#        2022-10-07, 2022-10-10, 2022-10-11, 2022-10-12, 2022-10-13, 2022-10-14,
#        2022-10-17, 2022-10-18, 2022-10-19, 2022-10-20],
#       dtype='object', name='Date', length=4419)

# %% [markdown]
# **!!!!!!!!!!!!!!!!!!!!!!!!**

# %%
Companies = [df_maruti, df_al, df_sbi, df_axis]
Companies_Title = ["Maruti", "Ashok Leyland", "SBI", "AXIS Bank"]

# %%
for company in Companies:
  company["Daily Return"] = company['Close'].pct_change()

# %%
for company in Companies:
  company['Date'] = company.index

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Daily Return"])
  plt.title(Companies_Title[index])
  plt.ylabel('Daily Return')

# %%
plt.figure(figsize=(20, 15))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color = "purple")
  plt.title(Companies_Title[index])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **@@@@@@@@@@@@@@@@@@@@@@@@@@@**

# %% [markdown]
# **Checking for null values**

# %%
#Info 
import warnings
warnings.filterwarnings('ignore')
for i in range(0,len(datas)):
  print('\n Stock Name: {}\n'.format(names[i]))
  datas[i].info()
# Out:
#  Stock Name: SBI
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 4419 entries, 2005-01-03 to 2022-10-20
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Symbol        4419 non-null   object
#  1   Prev Close    4419 non-null   float64
#  2   Open          4419 non-null   float64
#  3   High          4419 non-null   float64
#  4   Low           4419 non-null   float64
#  5   Last          4419 non-null   float64
#  6   Close         4419 non-null   float64
#  7   Volume        4419 non-null   int64
#  8   Daily Return  4418 non-null   float64
#  9   Date          4419 non-null   object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 379.8+ KB
#
#  Stock Name: Maruti
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 4419 entries, 2005-01-03 to 2022-10-20
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Symbol        4419 non-null   object
#  1   Prev Close    4419 non-null   float64
#  2   Open          4419 non-null   float64
#  3   High          4419 non-null   float64
#  4   Low           4419 non-null   float64
#  5   Last          4419 non-null   float64
#  6   Close         4419 non-null   float64
#  7   Volume        4419 non-null   int64
#  8   Daily Return  4418 non-null   float64
#  9   Date          4419 non-null   object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 379.8+ KB
#
#  Stock Name: AXIS
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 4419 entries, 2005-01-03 to 2022-10-20
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Symbol        4419 non-null   object
#  1   Prev Close    4419 non-null   float64
#  2   Open          4419 non-null   float64
#  3   High          4419 non-null   float64
#  4   Low           4419 non-null   float64
#  5   Last          4419 non-null   float64
#  6   Close         4419 non-null   float64
#  7   Volume        4419 non-null   int64
#  8   Daily Return  4418 non-null   float64
#  9   Date          4419 non-null   object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 379.8+ KB
#
#  Stock Name: Ashok leyland
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 4419 entries, 2005-01-03 to 2022-10-20
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Symbol        4419 non-null   object
#  1   Prev Close    4419 non-null   float64
#  2   Open          4419 non-null   float64
#  3   High          4419 non-null   float64
#  4   Low           4419 non-null   float64
#  5   Last          4419 non-null   float64
#  6   Close         4419 non-null   float64
#  7   Volume        4419 non-null   int64
#  8   Daily Return  4418 non-null   float64
#  9   Date          4419 non-null   object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 379.8+ KB

# %% [markdown]
# There are no null values in the data set.

# %%
df_sbi
# Out:
#            Symbol  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2005-01-03   SBIN      652.00  654.50  662.90  650.10  657.00  655.75
# 2005-01-04   SBIN      655.75  658.85  658.90  646.15  651.00  649.90
# 2005-01-05   SBIN      649.90  649.95  655.80  591.00  615.80  617.45
# 2005-01-06   SBIN      617.45  615.25  628.90  596.15  604.00  604.30
# 2005-01-07   SBIN      604.30  609.40  619.95  605.25  615.90  615.65
# ...           ...         ...     ...     ...     ...     ...     ...
# 2022-10-14   SBIN      521.45  530.20  534.85  526.00  527.80  527.20
# 2022-10-17   SBIN      527.20  526.40  544.70  524.20  543.20  543.65
# 2022-10-18   SBIN      543.65  547.10  563.50  546.75  562.40  562.45
# 2022-10-19   SBIN      562.45  563.00  563.45  551.55  553.75  553.40
# 2022-10-20   SBIN      553.40  552.00  556.80  545.30  555.50  555.40
#
#               Volume  Daily Return        Date
# Date
# 2005-01-03   2131452           NaN  2005-01-03
# 2005-01-04   2472630     -0.008921  2005-01-04
# 2005-01-05   4919738     -0.049931  2005-01-05
# 2005-01-06   4502406     -0.021297  2005-01-06
# 2005-01-07   2923563      0.018782  2005-01-07
# ...              ...           ...         ...
# 2022-10-14   8545479      0.011027  2022-10-14
# 2022-10-17  13485349      0.031203  2022-10-17
# 2022-10-18  20440781      0.034581  2022-10-18
# 2022-10-19   9540583     -0.016090  2022-10-19
# 2022-10-20  11225588      0.003614  2022-10-20
#
# [4419 rows x 10 columns]

# %% [markdown]
# **Setting index position**

# %%
#Coverting the return type of the date column
df_sbi['Date']=pd.to_datetime(df_sbi['Date'])
df_axis['Date']=pd.to_datetime(df_axis['Date'])
df_maruti['Date']=pd.to_datetime(df_maruti['Date'])
df_al['Date']=pd.to_datetime(df_al['Date'])

# %%
#Resetting index postion with date column
df_sbi.set_index('Date',inplace=True)
df_axis.set_index('Date',inplace=True)
df_al.set_index('Date',inplace=True)
df_maruti.set_index('Date',inplace=True)

# %% [markdown]
# # **Time Series resampling**

# %% [markdown]
# Comparison of min and max close price year wise

# %% [markdown]
# **SBI**

# %%
#Comparison of max and min close price year wise
plt.figure(figsize=(15,5))
df_sbi.resample(rule='A').min()['Close'].plot(label='Min')    #Resampling to week level and the criterion for resampling is min
df_sbi.resample(rule='A').max()['Close'].plot(label='Max')
plt.legend()
plt.title('SBI: Close price V/S Year',color='Blue',fontsize=15)
# Out:
# Text(0.5, 1.0, 'SBI: Close price V/S Year')

# %% [markdown]
# **AXIS Bank**

# %%
plt.figure(figsize=(15,5))
df_axis.resample(rule='A').min()['Close'].plot(label='Min')    #Resampling to week level and the criterion for resampling is min
df_axis.resample(rule='A').max()['Close'].plot(label='Max')
plt.legend()
plt.title('AXIS: Close price V/S Year',color='Blue',fontsize=15)
# Out:
# Text(0.5, 1.0, 'AXIS: Close price V/S Year')

# %%
plt.figure(figsize=(15,5))
df_al.resample(rule='A').min()['Close'].plot(label='Min')    #Resampling to week level and the criterion for resampling is min
df_al.resample(rule='A').max()['Close'].plot(label='Max')
plt.legend()
plt.title('ASHOK LEYLAND: Close price V/S Year',color='Blue',fontsize=15)
# Out:
# Text(0.5, 1.0, 'ASHOK LEYLAND: Close price V/S Year')

# %%
plt.figure(figsize=(15,5))
df_maruti.resample(rule='A').min()['Close'].plot(label='Min')    #Resampling to week level and the criterion for resampling is min
df_maruti.resample(rule='A').max()['Close'].plot(label='Max')
plt.legend()
plt.title('MARUTI: Close price V/S Year',color='Blue',fontsize=15)
# Out:
# Text(0.5, 1.0, 'MARUTI: Close price V/S Year')

# %%
#Resampling the data into week basis
sbi=df_sbi.resample(rule='w').mean()
maruti=df_maruti.resample(rule='w').mean()
al=df_al.resample(rule='w').mean()
axis=df_al.resample(rule='w').mean()

# %% [markdown]
# **After Downsampling**

# %%
sbi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 929 entries, 2005-01-09 to 2022-10-23
# Freq: W-SUN
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Prev Close               929 non-null    float64
#  1   Open                     929 non-null    float64
#  2   High                     929 non-null    float64
#  3   Low                      929 non-null    float64
#  4   Last                     929 non-null    float64
#  5   Close                    929 non-null    float64
#  6   Volume                   929 non-null    float64
#  7   Daily Return             929 non-null    float64
#  8   5 week Moving            925 non-null    float64
#  9   5 Week rolling average   925 non-null    float64
#  10  10 week rolling average  920 non-null    float64
# dtypes: float64(11)
# memory usage: 87.1 KB

# %%
maruti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 929 entries, 2005-01-09 to 2022-10-23
# Freq: W-SUN
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Prev Close               929 non-null    float64
#  1   Open                     929 non-null    float64
#  2   High                     929 non-null    float64
#  3   Low                      929 non-null    float64
#  4   Last                     929 non-null    float64
#  5   Close                    929 non-null    float64
#  6   Volume                   929 non-null    float64
#  7   Daily Return             929 non-null    float64
#  8   5 Week rolling average   925 non-null    float64
#  9   10 week rolling average  920 non-null    float64
# dtypes: float64(10)
# memory usage: 79.8 KB

# %%
al.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 929 entries, 2005-01-09 to 2022-10-23
# Freq: W-SUN
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Prev Close               929 non-null    float64
#  1   Open                     929 non-null    float64
#  2   High                     929 non-null    float64
#  3   Low                      929 non-null    float64
#  4   Last                     929 non-null    float64
#  5   Close                    929 non-null    float64
#  6   Volume                   929 non-null    float64
#  7   Daily Return             929 non-null    float64
#  8   5 Week rolling average   925 non-null    float64
#  9   10 week rolling average  920 non-null    float64
# dtypes: float64(10)
# memory usage: 79.8 KB

# %%
axis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 929 entries, 2005-01-09 to 2022-10-23
# Freq: W-SUN
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Prev Close               929 non-null    float64
#  1   Open                     929 non-null    float64
#  2   High                     929 non-null    float64
#  3   Low                      929 non-null    float64
#  4   Last                     929 non-null    float64
#  5   Close                    929 non-null    float64
#  6   Volume                   929 non-null    float64
#  7   Daily Return             929 non-null    float64
#  8   5 Week rolling average   925 non-null    float64
#  9   10 week rolling average  920 non-null    float64
# dtypes: float64(10)
# memory usage: 79.8 KB

# %% [markdown]
# # Rolling average

# %% [markdown]
# **Smoothing**

# %%
#For loop to get rolling average
company_name=[sbi,axis,maruti,al]   #list which holds the data frame 
for i in company_name:
  i['5 Week rolling average']=i['Close'].rolling(5).mean()

# %%
name=['SBI','AXIS BANK','MARUTI','ASHOK LEYLAND']
plt.figure(figsize=(20,20))
for i in range(0,4):
  plt.subplot(4,1,i+1)
  company_name[i]['5 Week rolling average'].plot(color='blue',label='Close 5 week rolling average')
  company_name[i]['Close'].plot(label='Close',color='red')
  plt.title(name[i])
  plt.legend()

# %% [markdown]
# # Decomposition Plots

# %%
#Maruti
from statsmodels.tsa.seasonal import seasonal_decompose
decomp=seasonal_decompose(df_maruti.Close,freq=5)
decomp.plot()
plt.show()

# %% [markdown]
# Show an overall non linear increasing trend.
# No seasonality is observed.

# %%
#Ashok leyland
decomp=seasonal_decompose(df_al.Close,freq=5)
decomp.plot()
plt.show()

# %% [markdown]
# Gradual increasing trend can be observed.
# There is no seasonal effects on the close price

# %%
#AXIS
decomp=seasonal_decompose(df_axis.Close,freq=5)
decomp.plot()
plt.show()

# %%
decomp=seasonal_decompose(df_sbi.Close,freq=5)
decomp.plot()
plt.show()

# %% [markdown]
# # Box plots

# %%
sbi_=df_sbi.reset_index()
maruti_=df_maruti.reset_index()
axis_bank=df_axis.reset_index()
ashok=df_al.reset_index()

# %%
#Creating month columns
sbi_['month']=pd.DatetimeIndex(sbi_['Date']).month
maruti_['month']=pd.DatetimeIndex(maruti_['Date']).month
axis_bank['month']=pd.DatetimeIndex(axis_bank['Date']).month
ashok['month']=pd.DatetimeIndex(ashok['Date']).month

# %%
#Creating year columns
sbi_['year']=pd.DatetimeIndex(sbi_['Date']).year
maruti_['year']=pd.DatetimeIndex(maruti_['Date']).year
axis_bank['year']=pd.DatetimeIndex(axis_bank['Date']).year
ashok['year']=pd.DatetimeIndex(ashok['Date']).year

# %%
c_name=[sbi_,maruti_,axis_bank,ashok]
c_names=['SBI','Maruti','Axis bank','Ashok leyland']
plt.figure(figsize=(15,15))
for i in range(0,len(c_name)):
  plt.subplot(2,2,i+1)
  sns.boxplot(x='month',y='Close',data=c_name[i])
  plt.title(c_names[i])

# %%
plt.figure(figsize=(25,15))
for i in range(0,len(c_name)):
  plt.subplot(2,2,i+1)
  sns.boxplot(x='year',y='Close',data=c_name[i])
  plt.title(c_names[i])
